# %% [markdown]
# \#Guess the number
#
# n = 18
#
# i = 1
#
# while(i\<=5):
#
#   print("Enter a number")
#
#   x = int(input())
#
#   if x == n:
#
#     print("u guessed the number correctly")
#
#     break
#
#   elif x\<n:
#
#     print("try greater number")
#
#     print("Chances left =",5-i)
#
#     i+=1
#
#     continue
#
#   elif x\>n:
#
#     print("try smaller number")
#
#     print("Chances left =",5-i)
#
#     i+=1
#
#     continue
#
# while i\>5:
#
#     print("SORRY!!!,UR out of moves")
#
#     break
